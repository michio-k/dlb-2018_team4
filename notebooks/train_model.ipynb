# %% [markdown]
# # モデルの作成

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git
# Out:
# fatal: destination path 'keras-retinanet' already exists and is not an empty directory.

# %%
# !pip install keras-retinanet

# %%
# !wc -l 'drive/My Drive/openimages/annotations.csv'
# Out:
# 33417 drive/My Drive/openimages/annotations.csv

# %%
# !retinanet-train --tensorboard-dir='drive/My Drive/tensorboard_logs/' --snapshot 'drive/My Drive/snapshots/resnet50_csv_01.h5' --snapshot-path='drive/My Drive/snapshots/' --epochs=10 --steps=33417 csv 'drive/My Drive/openimages/annotations.csv' 'drive/My Drive/openimages/classes.csv'
# Out:
# Using TensorFlow backend.
# 2019-03-25 09:50:19.103475: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-03-25 09:50:19.103725: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1b9f340 executing computations on platform Host. Devices:
# 2019-03-25 09:50:19.103797: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-03-25 09:50:19.194604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-25 09:50:19.195159: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1b9ec60 executing computations on platform CUDA. Devices:
# 2019-03-25 09:50:19.195195: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# ...
